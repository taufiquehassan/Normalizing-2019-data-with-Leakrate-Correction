# %% [markdown]
# ## Normalizing 2019 data with Leakrate Correction

# %%
#Importing the required libraries
from __future__ import print_function
import h5py
import argparse
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os

# %%
path_dir = os.path.dirname("C:/LANL/Data/LANLnEDM/Storage Measurement_2019/WGV Normalization_Old Switcher_WithCuts_BgSub_09.08.2020_Data Sent to Doug/")  #Directory where the files are

# %%
file_in= "leakRateCorrection.csv"   #electrode on and motor turning
#file_in= "coil_1000gain_april21_pos8_r1.hdf"

# loading the data 
file_name = os.path.join(path_dir, file_in)
df = pd.read_csv(file_name)
df
# Out:
#      run  bField                runCondition  holdTime  detectorCount  \
# 0    514   0.000    NoWindow_OldSw_MetalWall        30       77320.68
# 1    515   0.000    NoWindow_OldSw_MetalWall        40       68494.44
# 2    516   0.000    NoWindow_OldSw_MetalWall        50       60339.44
# 3    517   0.000    NoWindow_OldSw_MetalWall       100       35094.40
# 4    518   0.000    NoWindow_OldSw_MetalWall       125       28347.96
# ..   ...     ...                         ...       ...            ...
# 96   674   0.625  WithWindow_OldSw_MetalWall       100       22228.72
# 97   675   0.625  WithWindow_OldSw_MetalWall       250        4762.68
# 98   676   0.625  WithWindow_OldSw_MetalWall       300        3354.56
# 99   677   0.625  WithWindow_OldSw_MetalWall       150       12225.60
# 100  678   0.625  WithWindow_OldSw_MetalWall        80       28658.40
#
#      adc2Cut  adc4Cut  weightedLeak  correctedCounts
# 0         30        0    782.208746     78102.888750
# ...
